# %% [markdown]
# * 두 수의 합을 계산해서 합을 계산하되 합이 15 이상 20 미만이면 20을 반환하는 함수를 작성하시오.

# %%
def sum(x, y):
    sum = x + y
    if 15 <= sum < 20:
        return 20
    else:
        return sum

print(sum(10, 6))
print(sum(10, 2))
print(sum(10, 12))
# Out:
# 20
# 12
# 22

# %% [markdown]
# * 문자열을 두 개를 매개변수로 받아서 첫 문자열 중간에 두 번째 문자열을 삽입한 문자열을 만들어주는 함수를 작성하시오.

# %%
def insert_string_middle(first_str, second_str):
    pos = int(len(first_str) / 2)
    return first_str[:pos] + second_str + first_str[pos:]

print(insert_string_middle('[[]]', 'Python'))
print(insert_string_middle('{{}}', 'PHP'))
print(insert_string_middle('<<>>', 'HTML'))
# Out:
# [[Python]]
# {{PHP}}
# <<HTML>>

# %% [markdown]
# * 숫자가 저장된 자료구조(리스트, 튜플)를 매개변수로 받아 저장된 숫자의 곱을 계산해주는 함수를 작성하시오.
#
# Note: 매개변수의 타입을 검사하고 오류를 발생시키는 방법을 생각해보시오.

# %%
def multiply(numbers):  
    total = 1
    for x in numbers:
        total *= x  
    return total

print(multiply((8, 2, 3, -1, 7)))
# Out:
# -336

# %% [markdown]
# * 계승(factorial)을 계산하는 **재귀함수**(recursive function)를 작성하시오.
#
# Note: 재귀함수는 자기 자신을 호출하는 함수를 말한다. 즉, 함수의 몸체에 자신을 호출하는 코드가 들어 있는 함수를 말한다.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
    
n = int(input("양의 정수: "))
print(factorial(n))
# Out:
# 양의 정수: 5
# 120

# %% [markdown]
# * 매개변수로 받은 값이 3과 9 사이에 있는지를 검사하는 함수를 작성하시오.

# %%
def is_in_range(n):
    if 3 <= n <= 9:
        return True
    else :
        return False

is_in_range(5.5)
# Out:
# True

# %% [markdown]
# * 매개변수로 받은 문자열에서 대문자와 소문자의 개수를 계산해주는 프로그램을 작성하시오.

# %%
def count_cases(s):
    d = {"UPPER_CASE":0, "LOWER_CASE":0}
    for c in s:
        if c.isupper():
            d["UPPER_CASE"]+=1
        elif c.islower():
            d["LOWER_CASE"]+=1
        else:
            pass
    return d

count_cases('The quick Brow Fox 한글은 ... 문장 부호도 ')
# Out:
# {'LOWER_CASE': 12, 'UPPER_CASE': 3}

# %% [markdown]
# * 매개변수로 받은 리스트에서 동일한 값을 제거한 리스트를 만들어 주는 함수를 작성하시오.

# %%
def unique_list(lst):
    x = []
    for a in lst:
        if a not in x:
            x.append(a)
    return x

print(unique_list([1,2,3,3,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
def unique_list2(lst):
    return list(set(lst))

print(unique_list2([1,2,3,3,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# * 양의 정수를 받아서 소수(prime number)인지를 검사하는 함수를 작성하시오.

# %%
def is_prime(n):
    if (n==1):
        return False
    elif (n==2):
        return True;
    else:
        for x in range(2, n):
            if(n % x == 0):
                return False
        return True
    
print(is_prime(9))
# Out:
# False

# %% [markdown]
# * 정수가 저장된 리스트를 받아서 짝수만 추출하여 리스트를 만들어주는 함수를 작성하시오.

# %%
def select_even_number(lst):
    even_number = []
    for number in lst:
        if number % 2 == 0:
            even_number.append(number)
    return even_number

print(select_even_number([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# * 매개변수로 받은 문자열이 pangram인지를 검사하는 함수를 작성하시오. pangram은 모든 알파벳이 다 이용된 문자열을 말한다. 일반화시켜서 문자열이 지정한 문자들로만 이루어졌는지 검사하는 함수를 작성하시오.

# %%
import string, sys
def is_pangram(string, alphabet=string.ascii_lowercase):
    alphaset = set(alphabet)
    return alphaset.issubset(set(string.lower()))
 
print (is_pangram('The quick brown fox jumps over the lazy dog'))
# Out:
# True

# %% [markdown]
# * 정의된 함수에 대한 정보 즉, 함수 내에 정의된 지역변수의 이름과 개수를 알아보는 방법을 알아보시오.

# %%
def abc():
    x = 1
    y = 2
    str1= "w3resource"
    print("Python Exercises")

print(abc.__code__.co_varnames)
print(abc.__code__.co_nlocals)
# Out:
# ('x', 'y', 'str1')
# 3

# %% [markdown]
# * 문자열에서 지정된 문자를 제거한 문자열을 만들어 주는 함수를 작성하시오.

# %%
def remove_chars(str, chars):
    return "".join([c for c in str if c not in chars])

text = "The quick brown fox jumps over the lazy dog."
chars_to_remove = "aeiou"

print(remove_chars(text, chars_to_remove))
# Out:
# Th qck brwn fx jmps vr th lzy dg.

# %% [markdown]
# * 음식 이름을 key, 가격을 value로 하는 사전으로 메뉴를 표현하였다.
# 사전을 매개변수로 받아 메뉴를 보여주는 함수를 작성하시오.

# %% [markdown]
# * 음식 이름을 key, 주문량을 value로 하는 사전으로 고객을 주문을 표현하였다.
# 주문을 표현한 사전과 메뉴 사전을 매개변수로 받아서 총금액을 계산하는 함수를 작성하시오.
