# %% [markdown]
# # 자료구조: 튜플(tuple)과 셋(set)

# %% [markdown]
# ## 튜플
#
# 튜플(tuple)은 수학적 개념인 순서쌍을 구현한 자료구조이다.
# 튜플을 생성하는 방법은 `[]` 대신 `()`를 사용한다는 점을 제외하면 리스트와 동일하다.
# 튜플도 인덱스를 이용해서 저장된 값에 접근한다.
# 튜플과 리스트의 가장 큰 차이점은 리스트는 `mutable`하지만 튜플은 `immutable`하다는 것이다.
# 따라서 일단 생성된 튜플은 수정할 수 없다.
# 즉 값을 수정하거나 추가하거나 삭제할 수 없다.
# 따라서 리스트 자료구조와 달리 `append()`, `remove()`, `insert()`, `clear()` 등과 같은 메소드는 없다.

# %%
heam = ('Darwin Dawkins Park', 184, 76)
print(type(heam))
print(heam)
# Out:
# <class 'tuple'>
# ('Darwin Dawkins Park', 184, 76)

# %%
print(heam[1])
print(heam[:2])
print(184 in heam)
# Out:
# 184
# ('Darwin Dawkins Park', 184)
# True

# %%
for value in heam:
    print(value)
# Out:
# Darwin Dawkins Park
# 184
# 76

# %%
for idx, value in enumerate(heam):
    print(idx, value)
# Out:
# 0 Darwin Dawkins Park
# 1 184
# 2 76

# %%
print(len(heam))
print(heam.count(184))
print(heam.index(184))
# Out:
# 3
# 1
# 1

# %%
heam[0] = 'Charles Darwin'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-85eb676e0202> in <module>()
# ----> 1 heam[0] = 'Charles Darwin'
#
# TypeError: 'tuple' object does not support item assignment

# %%
heam.append(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-879c43c59aee> in <module>()
# ----> 1 heam.append(30)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# 리스트 자료구조와 같이 **튜플 간의 `+` 연산과 튜플에 대한 정수 곱셈 연산이 가능**하다.
# 이들 연산은 **피연산자인 튜플을 변경하는 것이 아니라 연산 결과를 새로운 튜플로 주기 때문에 가능하다.**
# 따라서 이들 연산 결과를 저장해야 다른 연산에 사용할 수 있다.

# %%
print(heam + heam)
print(heam * 3)
print(heam)
# Out:
# ('Darwin Dawkins Park', 184, 76, 'Darwin Dawkins Park', 184, 76)
# ('Darwin Dawkins Park', 184, 76, 'Darwin Dawkins Park', 184, 76, 'Darwin Dawkins Park', 184, 76)
# ('Darwin Dawkins Park', 184, 76)

# %% [markdown]
# **내장함수 `list()`, `tuple()`를 사용하면 리스트를 튜플로 또는 튜플을 리스트로 변환할 수 있다.**

# %%
gender = ['M']*2 + ['F']*4 + ['M'] + ['F']*2 + ['M'] + \
        ['F']*2 + ['M'] + ['F']*4 + ['M']*2
weight = [62.0, 62.9, 36.1, 54.6, 48.5, 42.0, 47.4, \
          50.6, 42.0, 48.7, 40.3, 33.1, 51.9, 42.4, \
          34.5, 51.1, 41.2, 51.9, 46.9]
metabolic_rate = [1792, 1666, 995, 1425, 1396, 1418, 1362, 1502,\
        1256, 1614, 1189, 913, 1460, 1124, 1052, 1347,\
        1204, 1867, 1439]

# %%
print(type(gender))
gender = tuple(gender)
print(type(gender))
gender = list(gender)
print(type(gender))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# ### 패킹(packing)
#
# **여러 값을 한 변수에 저장하면 해당 변수는 자동적으로 모든 값을 저장한 튜플이 된다.**
# 이런 연산을 **패킹**이라 한다.

# %%
pack = 'joongyang' + ' ' + 'park', 'GNU', 12345, 3.141592
print(type(pack))
print(pack)
# Out:
# <class 'tuple'>
# ('joongyang park', 'GNU', 12345, 3.141592)

# %% [markdown]
# 튜플에 unpacking을 적용할 수 있다.
# 이때 2개 이상의 원소를 저장해야 할 경우에는 리스트가 이용된다.

# %%
elem1, *elems = pack
print(elem1, elems)
# Out:
# joongyang park ['GNU', 12345, 3.141592]

# %% [markdown]
# 튜플과 리스트 중 어떤 자료구조를 이용하는 것이 좋은가는 문제와 상황에 달려 있다.
# 기본적으로 자료구조에 저장된 값들이 변경해야 할 경우가 있느냐 없느냐에 달려 있다.

# %% [markdown]
# ## 셋
#
# 값을 저장한 순서가 중요한 리스트나 튜플과 달리 **셋**(set)은 **값의 순서는 아무런 의미가 없고 값의 중복도 허용하지 않는 자료구조**이다.
# 셋은 수학적 개념인 **집합을 구현한 자료구조**라고 할 수 있다.
# 값이 저장된 순서에 아무 의미도 없기 때문에 리스트와 튜플에서 사용했던 **인덱스와 `[]`연산자를 셋에서는 사용할 수 없다.**
# 셋은 `mutable`하기 때문에 새로운 원소를 추가/삭제할 수 있으며, **특정한 값이 집합의 원소인가를 알아 보는 연산, 합집합 연산, 교집합 연산, 차집합 연산** 등을 수행하는 메소드와 연산자가 구현되어 있다.

# %% [markdown]
# **셋은 쉼표로 구분한 원소를 `{}`로 감싸서 생성한다.**
# 원소가 하나인 셋을 생성할 때도 값 뒤에 쉼표를 기재해야 한다.

# %%
A = {'가', '나', '다'}
print(A)
print(type(A))
# Out:
# {'다', '가', '나'}
# <class 'set'>

# %% [markdown]
# **셋에 원소 하나를 추가할 때는 `add()` 메소드를 사용하고, 여러 개의 원소를 추가할 때는 추가할 원소의 리스트를 인자로 `update()` 메소드를 호출하면 된다.**
# 동일한 값을 여러 번 추가할 수는 있지만 셋은 중복을 허용하지 않기 때문에 한 번만 저장한다.

# %%
A.add('라')
print(A)
A.update(['라', '라', '마', '마'])
print(A)
# Out:
# {'다', '가', '라', '나'}
# {'다', '가', '마', '라', '나'}

# %% [markdown]
# `list()` 함수와 `tuple()` 함수와 같이 `set()` 함수를 이용하면 리스트와 튜플을 셋으로 변환할 수 있다.

# %%
temp = set(['라', '라', '마', '마'])
print(type(temp))
print(temp)
temp = tuple(temp)
print(type(temp))
print(temp)
temp = list(temp)
print(type(temp))
print(temp)
A.update(temp)
print(A)
# Out:
# <class 'set'>
# {'라', '마'}
# <class 'tuple'>
# ('라', '마')
# <class 'list'>
# ['라', '마']
# {'다', '가', '마', '라', '나'}

# %% [markdown]
# 특정한 값을 제거하고자 하면 제거할 값을 인자로 **`discard()`** 또는 **`remove()`** 메소드를 호출하면 된다.

# %%
A.discard('가')
print(A)
A.remove('나')
print(A)
# Out:
# {'라', '나', '다', '마'}
# {'라', '다', '마'}

# %% [markdown]
# `discard()` 메소드와 `remove()` 메소드의 차이는 셋에 없는 값을 삭제할 때 나타난다.
# `discard()` 메소드는 셋에 없는 값을 삭제하려고 하면 그냥 무시하지만 `remove()` 메소드는 `KeyError` 오류를 발생시킨다.

# %%
A.discard('가')
print(A)
A.remove('가')
print(A)
# Out:
# {'라', '다', '마'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f19b4e8e32f7> in <module>()
#       1 A.discard('가')
#       2 print(A)
# ----> 3 A.remove('가')
#       4 print(A)
#
# KeyError: '가'

# %% [markdown]
# **특정한 값이 집합의 원소인가를 알아볼 때는 `in` 연산자, 합집합 연산은 `|` 연산자 또는 `union()` 메소드, 교집합 연산은 `&` 연산자 또는 `intersection()` 메소드, 차집합 연산은 `-` 연산자 또는 `difference()` 메소드를 이용**하여 수행할 수 있다.

# %%
print(A)
B = {'가', '나', '다'}
print(B)
# Out:
# {'다', '가', '마', '라', '나'}
# {'다', '가', '나'}

# %%
print('가' in A)
print('가' not in A)
# Out:
# True
# False

# %%
for ele in A:
    print(ele)
# Out:
# 다
# 가
# 마
# 라
# 나

# %%
AorB = A | B
AcupB = A.union(B)
print(AorB)
print(AcupB)
# Out:
# {'가', '라', '나', '마', '다'}
# {'가', '라', '나', '마', '다'}

# %%
AandB = A & B
AcapB = A.intersection(B)
print(AandB)
print(AcapB)
# Out:
# {'다', '가', '나'}
# {'다', '가', '나'}

# %%
AminusB = A - B
AdiffB = A.difference(B)
print(AminusB)
print(AdiffB)
BminusA = B - A
BdiffA = B.difference(A)
print(BminusA)
print(BdiffA)
# Out:
# {'라', '마'}
# {'라', '마'}
# set()
# set()

# %% [markdown]
# 그 외에도 한 집합이 다른 집합의 **부분집합(subset)**인지 **확대집합(superset)**인지 또는 서로소 집합인지를 검사하여 결과를 논리값으로 반환하는 **`issubset()`**, **`issuperset()`**, **`isdisjoint()`** 메소드가 있다.

# %%
ans = A.issubset(B)
print(ans)
# Out:
# False

# %%
if B.issubset(A):
    print("ulala!!!")
    
if B.isdisjoint(A):
    print("hahaha")
# Out:
# ulala!!!

# %% [markdown]
# ### 튜플과 셋에 사용할 수 있는 내장함수
#
# 내장함수 `all()`, `any()`, `enumerate()`, `len()`, `max()`, `min()`, `sorted()`, `sum()`은 리스트 자료구조 뿐만 아니라 튜플과 셋 자료구조에도 사용할 수 있다.

# %% [markdown]
# ## 연습문제
#
# 1. 다음 패킹 또는 언패킹의 결과를 예상해보시오.
#
#     * `a, b = "XY"`
#     * `a, b = range(1, 10, 3)`
#     * `a, *b = 1, 2, 3, 4, 5, 6`
#     * `a, *b, c = 1, 2, 3, 4, 5, 6`
#     * `a, *b = "X"`
#     * `a, *b, c = "XY"`
#     * `*a, b = [1]`
#
# 2. 전체집합 U, 부분집합 A, B가 아래와 같이 정의되어 있다. $A \cap B^c$와 $\left( A \cup B \right)^c$를 구하시오.
#
# ```python
# U = set(range(1, 11))
# A = {1, 3, 5, 7, 9}
# B = {1, 2, 3, 4, 5}
#
# ```
# 3. 100 이하의 자연수 중에서 2의 배수 또는 3의 배수의 집합을 만들어 보시오.
#
# 4. 전체 고객의 이름이 저장된 셋은 S, 지난 3개월간 구매한 적이 있는 고객의 이름이 저장된 셋은 C, 지난 3개월간 방문한 적이 있는 고객의 이름이 저장된 셋은 V이다.
#
#     * 지난 3개월간 구매한 적이 없는 고객의 명단을 구하시오.
#     * 지난 3개월간 방문한 적이 없는 고객의 명단을 구하시오.
#     * 지난 3개월간 방문했지만 구매한 적이 없는 고객의 명단을 구하시오.

# %% [markdown]
# 5. 10명의 연락처가 저장된 리스트 contacts를 만들고 다음 작업을 수행하는 예제 프로그램을 작성하시오.
#
#     * 10명 중에서 2명의 연락처가 저장된 차단 목록 리스트 rejects를 만드시오.
#     * 특정 연락처가 차단 목록에 들어 있는지를 검사하는 코드를 작성하시오.
#     * 차단 목록에 들어 있지 않는 연락처가 저장된 리스트 accepts를 만드시오.
#     * 리스트 rejects와 accepts에 없는 연락처가 있는지 확인하는 코드를 작성하시오.
#     * 새로운 연락처 2개를 contacts에 추가하는 코드를 작성하시오.
#     * 새로 추가한 연락처에서 한 개 연락처를 rejects에 추가하는 코드를 작성하시오.
#     * contacts와 rejects가 변경되었으므로 accepts를 다시 생성하는 코드를 작성하시오.
#     * 리스트 contacts에서 100개 연락처를 복원추출한 것을 저장한 리스트 calls는 최근에 연락한 연락처들이다. 어느 연락처에 몇 번 연락했는지를 구하시오.
